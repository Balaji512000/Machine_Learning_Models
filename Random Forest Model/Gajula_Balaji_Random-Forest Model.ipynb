# %% [raw]
# Random Forest
#
# Dataset Description:
#
# Use the Glass dataset and apply the Random forest model.
#
# 1. Exploratory Data Analysis (EDA):
#
# Perform exploratory data analysis to understand the structure of the dataset.
# Check for missing values, outliers, inconsistencies in the data.
#
# 2: Data Visualization:
#
# Create visualizations such as histograms, box plots, or pair plots to visualize the distributions and relationships between features.
# Analyze any patterns or correlations observed in the data.
#
# 3: Data Preprocessing
#
# 1. Check for missing values in the dataset and decide on a strategy for handling them.Implement the chosen strategy (e.g., imputation or removal) and explain your reasoning.
# 2. If there are categorical variables, apply encoding techniques like one-hot encoding to convert them into numerical format.
# 3. Apply feature scaling techniques such as standardization or normalization to ensure that all features are on a similar scale. Handling the imbalance data.
#
# 4: Random Forest Model Implementation
# 1. Divide the data into train and test split.
# 2. Implement a Random Forest classifier using Python and a machine learning library like scikit-learn.
# 3. Train the model on the train dataset. Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.
#
# 5: Bagging and Boosting Methods
# Apply the Bagging and Boosting methods and compare the results.
#
#
# Additional Notes:
# 1. Explain Bagging and Boosting methods. How is it different from each other.
# 2. Explain how to handle imbalance in the data.

# %%
import pandas as pd
df=pd.read_excel("glass.xlsx",sheet_name="glass")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.shape
# Out:
# (214, 10)

# %%
df.size
# Out:
# 2140

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
z=df.corr(numeric_only=True)
z
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(z,annot=True)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 209    False
# 210    False
# 211    False
# 212    False
# 213    False
# Length: 214, dtype: bool

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [213 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [raw]
# for col in df.columns:
#     sns.boxplot(data=df, x=col)
#     plt.title(f"Boxplot for {col}")
#     plt.show()

# %% [raw]
# for col in df.columns:
#     sns.histplot(data=df, x=col)
#     plt.title("Relationship Between Features")
#     plt.ylabel("Frequency")
#     plt.tight_layout()
#     plt.show()

# %%
#sns.pairplot(df)

# %%
x=df.iloc[:,:9]
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [213 rows x 9 columns]

# %%
y=df["Type"]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 213, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
imputer_num = SimpleImputer(strategy='mean')
df = imputer_num.fit_transform(df)

# %%
scaler = StandardScaler()
df = scaler.fit_transform(df)

# %%
df
# Out:
# array([[ 0.87984017,  0.28955813,  1.25723832, ..., -0.35380764,
#         -0.58830108, -0.85170346],
#        [-0.24381562,  0.59640332,  0.63931074, ..., -0.35380764,
#         -0.58830108, -0.85170346],
#        [-0.71641202,  0.15454625,  0.6045957 , ..., -0.35380764,
#         -0.58830108, -0.85170346],
#        ...,
#        [ 0.76086485,  1.17327228, -1.86017161, ...,  2.94550057,
#         -0.58830108,  2.0051916 ],
#        [-0.60735132,  1.19781989, -1.86017161, ...,  2.80467644,
#         -0.58830108,  2.0051916 ],
#        [-0.40905912,  1.01371278, -1.86017161, ...,  3.00585377,
#         -0.58830108,  2.0051916 ]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df,y,test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(random_state=42,n_jobs=-1,max_depth=5,n_estimators=100,oob_score=True)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 7, 1, 7, 2, 2, 1, 2, 2, 2, 6, 5, 2, 2, 6, 5, 7, 1, 1, 7, 2, 7,
#        7, 7, 3, 2, 1, 1, 6, 1, 1, 2, 3, 2, 2, 7, 5, 3, 2, 2, 2, 5, 1],
#       dtype=int64)

# %%
model.oob_score_
# Out:
# 0.9647058823529412

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[10,  0,  0,  0,  0,  0],
#        [ 0, 15,  0,  0,  0,  0],
#        [ 0,  0,  3,  0,  0,  0],
#        [ 0,  0,  0,  3,  0,  0],
#        [ 0,  0,  0,  0,  3,  0],
#        [ 0,  0,  0,  1,  0,  8]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00         3
#            5       0.75      1.00      0.86         3
#            6       1.00      1.00      1.00         3
#            7       1.00      0.89      0.94         9
#
#     accuracy                           0.98        43
#    macro avg       0.96      0.98      0.97        43
# weighted avg       0.98      0.98      0.98        43

# %%
# Accuracy - 98% - Excellent model

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Random Forest Accuracy (Bagging):", accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy (Bagging): 0.9767441860465116

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Use 'estimator' instead of 'base_estimator'
base_estimator = DecisionTreeClassifier(max_depth=1)
ada = AdaBoostClassifier(estimator=base_estimator, n_estimators=100, random_state=42)
ada.fit(x_train, y_train)
y_pred_ada = ada.predict(x_test)

# %%
print("AdaBoost Accuracy (Boosting):", accuracy_score(y_test, y_pred_ada))
# Out:
# AdaBoost Accuracy (Boosting): 0.6511627906976745

# %% [markdown]
# ###  1)Explain Bagging and Boosting methods. How is it different from each other.

# %% [raw]
# Bagging:
# Makes many models independently on random parts of the data, then averages their results to reduce mistakes caused by randomness. It helps make the model more stable and less likely to overfit.
#
# Boosting:
# Builds models one after another, where each new model tries to fix the errors of the previous ones. This helps the combined model get better and better at making predictions.
#
# Main difference:
# Bagging builds models in parallel and focuses on reducing errors due to random noise (variance), while Boosting builds models sequentially to fix errors and reduce bias.
#
#
# Bagging is like having many students solve a problem independently and then voting on the best answer.
#
# Boosting is like one student learning from the previous one's mistakes and getting better over time.

# %% [markdown]
# ###  2)Explain how to handle imbalance in the data.

# %% [raw]
# 1. Resampling Techniques
# 2. Oversampling (increase minority class)
# 3. Use of Class Weights
# 4. Ensemble Methods for Imbalanced Data
