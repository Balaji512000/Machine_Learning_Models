# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("EastWestAirlines.xlsx",sheet_name="data")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.info()  #information  #all are numerical columns only
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df.size
# Out:
# 47988

# %%
df.shape  #rows and columns
# Out:
# (3999, 12)

# %%
df.describe()    #mean,median,IQR,MIN and max, count values
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
df.head()  # first 5 rows
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.tail()  # first 5 columns
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 3994       1
# 3995       1
# 3996       1
# ...

# %%
df.columns   # column names of the data
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
z=df.corr(numeric_only=True)
z   # correlation assigned value z
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %%
# Correlation matrix
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,8))   #figure size
z=df.corr(numeric_only=True)
sns.heatmap(z,annot=True,cmap="coolwarm")  #annot to display correlation numbers
plt.title("Correlation matrix")   #title
plt.show()   #display

# %%
df.nunique()  #unique values
# Out:
# ID#                  3999
# Balance              3904
# Qual_miles            164
# cc1_miles               5
# cc2_miles               3
# cc3_miles               5
# Bonus_miles          2734
# Bonus_trans            57
# Flight_miles_12mo     343
# Flight_trans_12        35
# Days_since_enroll    2820
# Award?                  2
# dtype: int64

# %%
df.isnull().sum()  #total count of null values in every column
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
columns=df.columns    # assigned variable name to columns

# %%
# Histograms
import seaborn as sns
import matplotlib.pyplot as plt
for columns in df.columns:
    plt.figure(figsize=(6,4))  # fig sixe
    sns.histplot(df[columns], bins=30, kde=True,color='purple')  #kde= kernal density estimation, bins- data points to display in each column
    plt.title(f'Distribution of Frequent Flier Miles {columns}')   #title
    plt.xlabel(f'{columns}') 
    plt.ylabel('Count')
    plt.show()

# %%
# Boxplots
for columns in df.columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=columns, data=df,color='blue')
    plt.title('Flight Miles (last 12 months) vs Award Status')
    plt.xlabel('Award Status (0 = No, 1 = Yes)')
    plt.ylabel('Flight Miles in 12 Months')
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler   # ml technique for standardization to assign 0 for mean and 1 for standard deviation

# %%
x=df[['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
       'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
       'Days_since_enroll', 'Award?']]   # columns
scaler=StandardScaler()   
x_scaled=scaler.fit_transform(x)    #scaling x values for standardization

# %%
x_scaled   #scaled values of x
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
x   #normal x values
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### Implementing Clustering Algorithms:

# %% [markdown]
# # DBSCAN MODEL

# %%
from sklearn.cluster import DBSCAN     # importing dbscan for building model from scikitlearn
dbscan_model=DBSCAN(eps=3,min_samples=4,metric="euclidean")   #eps- radius btwn 2 points, #euclidean-straightline distance between 2 points
dbscan_model
# Out:
# DBSCAN(eps=3, min_samples=4)

# %%
dbscan_model.fit(x_scaled)  #fitted the model with scaled values of x
# Out:
# DBSCAN(eps=3, min_samples=4)

# %%
labels_db = dbscan_model.labels_ 
labels_db
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df.head(10)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
# 5    6    16420           0          1          1          1            0
# 6    7    84914           0          3          1          1        27482
# 7    8    20856           0          1          1          1         5250
# 8    9   443003           0          3          2          1         1753
# 9   10   104860           0          3          1          1        28426
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# ...

# %%
df.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
df["db_clusters"]=labels_db

# %%
df.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?', 'db_clusters'],
#       dtype='object')

# %%
y_means = dbscan_model.fit_predict(x_scaled)
y_means
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import silhouette_score   #silhouette_score=  -1 to 1 better score indicates better clustering 

# Calculating silhouette score   
score = silhouette_score(x_scaled, labels_db)          #-1 for bad clustering, 0 for some data point clustering moved to another cluster
print(f"Silhouette Score for dbscan: {score}")                    # 1 for good clustering
# Out:
# Silhouette Score for dbscan: 0.5128054200759178

# %% [markdown]
# ## Silhouette Score for dbscan: 0.5128054200759178

# %%
import numpy as np
y_means = dbscan_model.fit_predict(x_scaled)   #fitted model
plt.figure(figsize=(7,5))
colors = ['pink', 'yellow', 'cyan', 'magenta', 'orange', 'blue', 'red', 'black', 'violet', 'green']  # colors
unique_clusters = np.unique(y_means)  
for cluster_id in unique_clusters:
    if cluster_id == -1:
        # Noise points (optional, can be skipped or represented differently)
        cluster_color = 'gray'
        label = 'Noise'
    else:
        cluster_color = colors[cluster_id % len(colors)]
        label = f"cluster{cluster_id+1}"
    mask = y_means == cluster_id
    plt.scatter(x_scaled[mask, 0], x_scaled[mask, 1], s=50, c=cluster_color, label=label)
plt.title('Clusters of data')
plt.legend()
plt.show()

# %% [markdown]
# # K-Means Model

# %%
from sklearn.cluster import KMeans  #importing kmeans from sckit learn
wcss=[]
for i in range(1,11):  #range for clusters
  kmeans_model=KMeans(n_clusters=i,init="k-means++",random_state=1)
  kmeans_model.fit(x)            #fitting the model
  wcss.append(kmeans_model.inertia_)
# kmeans inertia measures how tightly the data points are clustered around the centroids.
# elbow methods.

# %%
kmeans_model=KMeans(n_clusters=5,init="k-means++",random_state=1)
y_kmeans=kmeans_model.fit_predict(x)
y_kmeans
# Out:
# array([0, 0, 0, ..., 3, 0, 0])

# %%
labels_kmeans = kmeans_model.labels_ 
labels_kmeans
# Out:
# array([0, 0, 0, ..., 3, 0, 0])

# %%
#Elbow method kmeans
import matplotlib.pyplot as plt
plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method K-Means")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
df["kmeans_clusters"]=labels_kmeans

# %%
df.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?', 'db_clusters', 'kmeans_clusters'],
#       dtype='object')

# %%
# Silhouette Score
from sklearn.metrics import silhouette_score
print("KMeans Silhouette Score:", silhouette_score(x,y_kmeans))
# Out:
# KMeans Silhouette Score: 0.5481756025079243

# %% [markdown]
# ## KMeans Silhouette Score: 0.5481756025079243

# %%
import matplotlib.pyplot as plt

plt.title("KMEANS CLUSTER (5 CLUSTERS)")

# Use .loc with boolean mask, then select columns appropriately
plt.scatter(x.loc[y_kmeans == 0, x.columns[0]], x.loc[y_kmeans == 0, x.columns[1]], s=60, c='red', label='cluster1')
plt.scatter(x.loc[y_kmeans == 1, x.columns[0]], x.loc[y_kmeans == 1, x.columns[1]], s=60, c='blue', label='cluster2')
plt.scatter(x.loc[y_kmeans == 2, x.columns[0]], x.loc[y_kmeans == 2, x.columns[1]], s=60, c='green', label='cluster3')
plt.scatter(x.loc[y_kmeans == 3, x.columns[0]], x.loc[y_kmeans == 3, x.columns[1]], s=60, c='violet', label='cluster4')
plt.scatter(x.loc[y_kmeans == 4, x.columns[0]], x.loc[y_kmeans == 4, x.columns[1]], s=60, c='yellow', label='cluster5')

# For centroids: kmeans.cluster_centers_ is a numpy array, so direct indexing works
plt.scatter(kmeans_model.cluster_centers_[:, 0], kmeans_model.cluster_centers_[:, 1], s=100, c='black', label='Centroids')

plt.legend()
plt.show()

# %% [markdown]
# # Hierarchical MODEL

# %%
from sklearn import preprocessing   #preprocessing imported
import scipy.cluster.hierarchy as sch    #hierarchy imported from scipy
from sklearn.cluster import AgglomerativeClustering   #imported agglomerativeclustering  from sklearn
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

# %%
link = sch.linkage(x_scaled, method='ward')

# %%
plt.figure(1, figsize = (16 ,8))
dendrogram = sch.dendrogram(sch.linkage(x_scaled, method="ward"))

plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# ## silhouette_score= the score is between -1 to 1,  better score indicates better clustering
#
# 1. KMeans Silhouette Score: 0.5481756025079243
# 2. DBScan Silhouette Score: 0.5128054200759178

# %%
# Linkage methods

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import dendrogram as dendrogram_func
linkage_methods = ['single', 'complete', 'average', 'ward']

for method in linkage_methods:
    plt.figure(figsize=(10, 5))
    Z = linkage(x_scaled, method=method)
    dendrogram(Z, truncate_mode="level", p=5)
    plt.title(f"Dendrogram using {method} linkage")
    plt.xlabel("Sample Index")
    plt.ylabel("Distance")
    plt.show()
